# %%
import doremi

# %%
doremi.compose("""

up = le.... la.... te.... ti....

high = {__ le.. __ le.. __ le.. __ le..}''

down = {le.. so.. se.. fa.. mi.. ti,.. me..}''

up

up
high

up
high
down

""").play()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
doremi.compose("""

up(x) = x x+ x++ x+++

high(rest x) = rest x rest x rest x rest x

down(x) = x x-1 x-2 x-3 x-4 x-8 x-5

up(le....)

up(le....)
high(__ le''..)

up(le....)
high(__ le''..)
down(le''..)

up(le....)
high(__ le''..)
down({le'' le''})

""").play()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
